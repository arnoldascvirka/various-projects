# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 24.2 MB/s eta 0:00:00
# ...
#      ------------------------------------- 956.5/956.5 kB 15.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB ? eta 0:00:00
# ...

# %%
df = pd.read_csv('miestai.csv')

# %%
df.info()
df2 = df[df.iloc[:,-1] > 10_000]
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Miestas  103 non-null    object
#  1   2021     103 non-null    int64
#  2   2011     103 non-null    int64
#  3   2001     103 non-null    int64
#  4   1989     103 non-null    int64
#  5   1979     103 non-null    int64
#  6   1970     103 non-null    int64
#  7   1959     103 non-null    int64
#  8   1923     103 non-null    int64
#  9   1897     103 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 8.2+ KB
#       Miestas    2021    2011    2001    1989    1979    1970    1959    1923  \
# 0     Vilnius  546155  524406  542287  576747  475825  372100  236078  167400
# 1      Kaunas  298753  315993  378943  418087  368649  305116  219287   92446
# 2    Klaipėda  152008  162360  192954  202929  176648  140012   90521   35845
# ...

# %%
df2.plot(x='Miestas', kind='bar')
# Out:
# <AxesSubplot:xlabel='Miestas'>

# %%
df2.iloc[:,:-4].plot(x='Miestas', kind='barh')
# Out:
# <AxesSubplot:ylabel='Miestas'>

# %%
df2.iloc[:,:-4].plot(x='Miestas', kind='area')
# Out:
# <AxesSubplot:xlabel='Miestas'>

# %%
df2.iloc[:,:-4].plot(x='Miestas', kind='bar', title='Miesų augimas', grid=True, ylabel='Gyventojų skaičius')
# Out:
# <AxesSubplot:title={'center':'Miesų augimas'}, xlabel='Miestas', ylabel='Gyventojų skaičius'>
