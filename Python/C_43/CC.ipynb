# %%
# %load_ext sql

# %%
# %sql sqlite:///database.db

# %%
# %%sql
# SELECT name, sql FROM sqlite_master
# WHERE type='table'
# ORDER BY name;
# Out:
#  * sqlite:///database.db
# Done.
# [('car', 'CREATE TABLE car (\r\n\tid INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,\r\n\tmake VARCHAR(50),\r\n\tmodel VARCHAR(50),\r\n\tplate VARCHAR(50)\r\n)'),
#  ('company', 'CREATE TABLE company (\r\n\tid INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,\r\n\tname VARCHAR(50)\r\n)'),
#  ('person', 'CREATE TABLE person (\r\n\tid INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,\r\n\tfirst_name VARCHAR(50),\r\n\tlast_name VARCHAR(50),\r\n\temail  ... (5 characters truncated) ... AR(50),\r\n\tcar_id INT,\r\n\tcompany_id INT,\r\n\tFOREIGN KEY (car_id) REFERENCES car(id),\r\n\tFOREIGN KEY (company_id) REFERENCES company(id)\r\n)'),
#  ('sqlite_sequence', 'CREATE TABLE sqlite_sequence(name,seq)')]

# %%
# %%sql
# SELECT first_name, last_name, make, plate, name
# FROM person, car, company
# WHERE person.car_id AND person.company_id = company.id
# ORDER BY name;
# Out:
#  * sqlite:///database.db
# Done.
# [('Claudetta', 'Dewey', 'BMW', 'LNP 014 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Kia', 'FRJ 254 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Ford', 'YUJ 630 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Suzuki', 'AWF 961 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Hyundai', 'ZPG 590 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Ford', 'LND 949 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Volvo', 'JVC 825 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Ford', 'VTQ 735 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Chevrolet', 'CTF 751 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Mercury', 'QMI 970 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Ford', 'KUO 362 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Land Rover', 'HPS 491 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Chrysler', 'DJK 821 ', 'Amazon'),
#  ('Claudetta', 'Dewey', 'Buick', 'YZD 474 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'BMW', 'LNP 014 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Kia', 'FRJ 254 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Ford', 'YUJ 630 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Suzuki', 'AWF 961 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Hyundai', 'ZPG 590 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Ford', 'LND 949 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Volvo', 'JVC 825 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Ford', 'VTQ 735 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Chevrolet', 'CTF 751 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Mercury', 'QMI 970 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Ford', 'KUO 362 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Land Rover', 'HPS 491 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Chrysler', 'DJK 821 ', 'Amazon'),
#  ('Irvine', 'Kenewell', 'Buick', 'YZD 474 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'BMW', 'LNP 014 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Kia', 'FRJ 254 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Ford', 'YUJ 630 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Suzuki', 'AWF 961 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Hyundai', 'ZPG 590 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Ford', 'LND 949 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Volvo', 'JVC 825 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Ford', 'VTQ 735 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Chevrolet', 'CTF 751 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Mercury', 'QMI 970 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Ford', 'KUO 362 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Land Rover', 'HPS 491 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Chrysler', 'DJK 821 ', 'Amazon'),
#  ('Frankie', 'Yaknov', 'Buick', 'YZD 474 ', 'Amazon'),
#  ('Carri', 'Sharpus', 'BMW', 'LNP 014 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Kia', 'FRJ 254 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Ford', 'YUJ 630 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Suzuki', 'AWF 961 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Hyundai', 'ZPG 590 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Ford', 'LND 949 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Volvo', 'JVC 825 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Ford', 'VTQ 735 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Chevrolet', 'CTF 751 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Mercury', 'QMI 970 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Ford', 'KUO 362 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Land Rover', 'HPS 491 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Chrysler', 'DJK 821 ', 'Apple'),
#  ('Carri', 'Sharpus', 'Buick', 'YZD 474 ', 'Apple'),
#  ('Lenore', 'Whatson', 'BMW', 'LNP 014 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Kia', 'FRJ 254 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Ford', 'YUJ 630 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Suzuki', 'AWF 961 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Hyundai', 'ZPG 590 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Ford', 'LND 949 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Volvo', 'JVC 825 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Ford', 'VTQ 735 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Chevrolet', 'CTF 751 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Mercury', 'QMI 970 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Ford', 'KUO 362 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Land Rover', 'HPS 491 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Chrysler', 'DJK 821 ', 'Apple'),
#  ('Lenore', 'Whatson', 'Buick', 'YZD 474 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'BMW', 'LNP 014 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Kia', 'FRJ 254 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Ford', 'YUJ 630 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Suzuki', 'AWF 961 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Hyundai', 'ZPG 590 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Ford', 'LND 949 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Volvo', 'JVC 825 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Ford', 'VTQ 735 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Chevrolet', 'CTF 751 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Mercury', 'QMI 970 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Ford', 'KUO 362 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Land Rover', 'HPS 491 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Chrysler', 'DJK 821 ', 'Apple'),
#  ('Randy', 'Hanscomb', 'Buick', 'YZD 474 ', 'Apple'),
#  ('Westbrook', 'Stirtle', 'BMW', 'LNP 014 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Kia', 'FRJ 254 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Ford', 'YUJ 630 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Suzuki', 'AWF 961 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Hyundai', 'ZPG 590 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Ford', 'LND 949 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Volvo', 'JVC 825 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Ford', 'VTQ 735 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Chevrolet', 'CTF 751 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Mercury', 'QMI 970 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Ford', 'KUO 362 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Land Rover', 'HPS 491 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Chrysler', 'DJK 821 ', 'Facebook'),
#  ('Westbrook', 'Stirtle', 'Buick', 'YZD 474 ', 'Facebook'),
#  ('Innis', 'Netley', 'BMW', 'LNP 014 ', 'Google'),
#  ('Innis', 'Netley', 'Kia', 'FRJ 254 ', 'Google'),
#  ('Innis', 'Netley', 'Ford', 'YUJ 630 ', 'Google'),
#  ('Innis', 'Netley', 'Suzuki', 'AWF 961 ', 'Google'),
#  ('Innis', 'Netley', 'Hyundai', 'ZPG 590 ', 'Google'),
#  ('Innis', 'Netley', 'Ford', 'LND 949 ', 'Google'),
#  ('Innis', 'Netley', 'Volvo', 'JVC 825 ', 'Google'),
#  ('Innis', 'Netley', 'Ford', 'VTQ 735 ', 'Google'),
#  ('Innis', 'Netley', 'Chevrolet', 'CTF 751 ', 'Google'),
#  ('Innis', 'Netley', 'Mercury', 'QMI 970 ', 'Google'),
#  ('Innis', 'Netley', 'Ford', 'KUO 362 ', 'Google'),
#  ('Innis', 'Netley', 'Land Rover', 'HPS 491 ', 'Google'),
#  ('Innis', 'Netley', 'Chrysler', 'DJK 821 ', 'Google'),
#  ('Innis', 'Netley', 'Buick', 'YZD 474 ', 'Google'),
#  ('Regan', 'Halliday', 'BMW', 'LNP 014 ', 'Google'),
#  ('Regan', 'Halliday', 'Kia', 'FRJ 254 ', 'Google'),
#  ('Regan', 'Halliday', 'Ford', 'YUJ 630 ', 'Google'),
#  ('Regan', 'Halliday', 'Suzuki', 'AWF 961 ', 'Google'),
#  ('Regan', 'Halliday', 'Hyundai', 'ZPG 590 ', 'Google'),
#  ('Regan', 'Halliday', 'Ford', 'LND 949 ', 'Google'),
#  ('Regan', 'Halliday', 'Volvo', 'JVC 825 ', 'Google'),
#  ('Regan', 'Halliday', 'Ford', 'VTQ 735 ', 'Google'),
#  ('Regan', 'Halliday', 'Chevrolet', 'CTF 751 ', 'Google'),
#  ('Regan', 'Halliday', 'Mercury', 'QMI 970 ', 'Google'),
#  ('Regan', 'Halliday', 'Ford', 'KUO 362 ', 'Google'),
#  ('Regan', 'Halliday', 'Land Rover', 'HPS 491 ', 'Google'),
#  ('Regan', 'Halliday', 'Chrysler', 'DJK 821 ', 'Google'),
#  ('Regan', 'Halliday', 'Buick', 'YZD 474 ', 'Google'),
#  ('Andras', 'Brownsea', 'BMW', 'LNP 014 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Kia', 'FRJ 254 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Ford', 'YUJ 630 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Suzuki', 'AWF 961 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Hyundai', 'ZPG 590 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Ford', 'LND 949 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Volvo', 'JVC 825 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Ford', 'VTQ 735 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Chevrolet', 'CTF 751 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Mercury', 'QMI 970 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Ford', 'KUO 362 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Land Rover', 'HPS 491 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Chrysler', 'DJK 821 ', 'Netflix'),
#  ('Andras', 'Brownsea', 'Buick', 'YZD 474 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'BMW', 'LNP 014 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Kia', 'FRJ 254 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Ford', 'YUJ 630 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Suzuki', 'AWF 961 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Hyundai', 'ZPG 590 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Ford', 'LND 949 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Volvo', 'JVC 825 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Ford', 'VTQ 735 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Chevrolet', 'CTF 751 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Mercury', 'QMI 970 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Ford', 'KUO 362 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Land Rover', 'HPS 491 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Chrysler', 'DJK 821 ', 'Netflix'),
#  ('Philippe', 'Longhirst', 'Buick', 'YZD 474 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'BMW', 'LNP 014 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Kia', 'FRJ 254 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Ford', 'YUJ 630 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Suzuki', 'AWF 961 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Hyundai', 'ZPG 590 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Ford', 'LND 949 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Volvo', 'JVC 825 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Ford', 'VTQ 735 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Chevrolet', 'CTF 751 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Mercury', 'QMI 970 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Ford', 'KUO 362 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Land Rover', 'HPS 491 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Chrysler', 'DJK 821 ', 'Netflix'),
#  ('Shelba', 'Gummer', 'Buick', 'YZD 474 ', 'Netflix'),
#  ('Nanny', 'Severns', 'BMW', 'LNP 014 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Kia', 'FRJ 254 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Ford', 'YUJ 630 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Suzuki', 'AWF 961 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Hyundai', 'ZPG 590 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Ford', 'LND 949 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Volvo', 'JVC 825 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Ford', 'VTQ 735 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Chevrolet', 'CTF 751 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Mercury', 'QMI 970 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Ford', 'KUO 362 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Land Rover', 'HPS 491 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Chrysler', 'DJK 821 ', 'Netflix'),
#  ('Nanny', 'Severns', 'Buick', 'YZD 474 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'BMW', 'LNP 014 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Kia', 'FRJ 254 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Ford', 'YUJ 630 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Suzuki', 'AWF 961 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Hyundai', 'ZPG 590 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Ford', 'LND 949 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Volvo', 'JVC 825 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Ford', 'VTQ 735 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Chevrolet', 'CTF 751 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Mercury', 'QMI 970 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Ford', 'KUO 362 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Land Rover', 'HPS 491 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Chrysler', 'DJK 821 ', 'Netflix'),
#  ('Dun', 'Zarfai', 'Buick', 'YZD 474 ', 'Netflix')]

# %%
# %%sql
#
# SELECT last_name, make, name
# FROM person, car, company
# WHERE person.car_id = car.id
# AND person.company_id = company.id
# AND make = "Ford"
# ORDER BY name DESC;
# Out:
#  * sqlite:///database.db
# Done.
# [('Stirtle', 'Ford', 'Facebook'),
#  ('Sharpus', 'Ford', 'Apple'),
#  ('Whatson', 'Ford', 'Apple'),
#  ('Yaknov', 'Ford', 'Amazon')]
